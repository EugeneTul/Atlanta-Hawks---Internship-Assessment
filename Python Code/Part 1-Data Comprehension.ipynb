# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv("nbaplayersdraft.csv")
df
# Out:
#         id  year  rank  overall_pick team                player  \
# 0        1  1989     1             1  SAC        Pervis Ellison
# 1        2  1989     2             2  LAC           Danny Ferry
# 2        3  1989     3             3  SAS          Sean Elliott
# 3        4  1989     4             4  MIA             Glen Rice
# 4        5  1989     5             5  CHH             J.R. Reid
# ...    ...   ...   ...           ...  ...                   ...
# 1917  1918  2021    56            56  CHO         Scottie Lewis
# 1918  1919  2021    57            57  CHO       Balša Koprivica
# 1919  1920  2021    58            58  NYK          Jericho Sims
# 1920  1921  2021    59            59  BRK          RaiQuan Gray
# 1921  1922  2021    60            60  IND  Georgios Kalaitzakis
#
#             college  years_active   games  minutes_played   points  \
# 0        Louisville          11.0   474.0         11593.0   4494.0
# ...

# %%
### wenk to Duke and were drafted on or before 2000

# %%
df_1=df[(df['college']=="Duke") & (df['year']<=2000)]
df_1
# Out:
#       id  year  rank  overall_pick team              player college  \
# 1      2  1989     2             2  LAC         Danny Ferry    Duke
# 78    79  1990    25            25  POR      Alaa Abdelnaby    Duke
# 102  103  1990    49            49  DAL      Phil Henderson    Duke
# 164  165  1992     3             3  MIN  Christian Laettner    Duke
# 209  210  1992    48            48  PHO         Brian Davis    Duke
# 222  223  1993     7             7  SAC        Bobby Hurley    Duke
# 254  255  1993    39            39  IND         Thomas Hill    Duke
# 272  273  1994     3             3  DET          Grant Hill    Duke
# 298  299  1994    29            29  PHO        Antonio Lang    Duke
# 335  336  1995    12            12  DAL      Cherokee Parks    Duke
# 364  365  1995    41            41  HOU           Erik Meek    Duke
# 516  517  1998    20            20  ATL      Roshown McLeod    Duke
# 555  556  1999     1             1  CHI         Elton Brand    Duke
# ...

# %%
df_1['team'].value_counts()
# Out:
# DAL    2
# MIN    2
# PHO    2
# LAC    1
# POR    1
# SAC    1
# IND    1
# DET    1
# HOU    1
# ATL    1
# CHI    1
# CLE    1
# SEA    1
# SAS    1
# Name: team, dtype: int64

# %%
### Have a first name starts with D and drafted in a even year
df_2=df[(df['player'].str.startswith('D')) & (df['year']% 2 == 0)]
df_2
# Out:
#         id  year  rank  overall_pick team           player  \
# 54      55  1990     1             1  NJN  Derrick Coleman
# 57      58  1990     4             4  ORL     Dennis Scott
# 68      69  1990    15            15  MIA    Dave Jamerson
# 71      72  1990    18            18  SAC   Duane Causwell
# 72      73  1990    19            19  BOS        Dee Brown
# ...    ...   ...   ...           ...  ...              ...
# 1734  1735  2018    53            53  OKC       Devon Hall
# 1810  1811  2020     9             9  WAS      Deni Avdija
# 1812  1813  2020    11            11  SAS    Devin Vassell
# 1831  1832  2020    30            30  BOS     Desmond Bane
# 1834  1835  2020    33            33  MIN     Daniel Oturu
#
#                       college  years_active  games  minutes_played   points  \
# 54                   Syracuse          15.0  781.0         25903.0  12884.0
# 57               Georgia Tech          10.0  629.0         17983.0   8094.0
# ...

# %%
df_2['team'].value_counts()
# Out:
# BOS    7
# SEA    7
# MIL    7
# ATL    6
# MIA    5
# SAS    5
# ORL    5
# NYK    4
# LAL    4
# DEN    4
# CHI    4
# DAL    4
# GSW    3
# UTA    3
# LAC    3
# MEM    3
# CLE    3
# PHO    3
# DET    3
# SAC    3
# WAS    2
# NOP    2
# NOH    2
# NJN    2
# TOR    2
# IND    2
# CHH    2
# MIN    2
# POR    2
# PHI    2
# CHA    1
# BRK    1
# HOU    1
# OKC    1
# Name: team, dtype: int64
